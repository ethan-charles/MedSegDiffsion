# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming the CSV has been loaded into a DataFrame named df
# df = pd.read_csv('path_to_your_csv.csv')

# Multiply loss and loss_cal by 100 to convert to percentage
df['loss'] *= 100
df['loss_cal'] *= 100

# Plot for grad_norm
plt.figure(figsize=(10, 5))
plt.plot(df['step'], df['grad_norm'], label='Grad Norm')
plt.xlabel('Step')
plt.ylabel('Grad Norm Value')
plt.title('Grad Norm in MedSegDiffsion')
plt.legend()
plt.show()

# Plot for loss and loss_cal
plt.figure(figsize=(10, 5))
plt.plot(df['step'], df['loss'], label='Loss')
plt.plot(df['step'], df['loss_cal'], label='Loss Cal')
plt.xlabel('Step')
plt.ylabel('Loss Value (%)')
plt.title('Loss Values in MedSegDiffsion')
plt.legend()
plt.show()
